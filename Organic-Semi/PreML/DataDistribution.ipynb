# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('C:../../../DCPdata100K.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  e_gap_alpha        ABC      ABCGG  nAcid  nBase    SpAbs_A  \
# 0           0     2.022944  20.142136  16.169815      0      0  33.204238
# 1           1     1.630750  20.849242  16.133746      0      0  34.755190
# 2           2     1.462158  22.889683  17.893320      0      0  37.437727
# 3           3     1.682250  13.313708  11.688393      0      0  21.283525
# 4           4     1.809439  19.435029  15.989365      0      0  31.670490
#
#     SpMax_A  SpDiam_A     SpAD_A  ...      SRW10     TSRW10          MW  \
# 0  2.616114  5.057172  33.204238  ...  10.460213  77.559765  394.963154
# 1  2.600656  5.047921  34.755190  ...  10.493799  77.890806  401.013897
# 2  2.645420  5.160050  37.437727  ...  10.639862  82.032579  363.107941
# 3  2.481194  4.637583  21.283525  ...   9.782393  66.966647  319.941201
# 4  2.627835  5.062549  31.670490  ...  10.429310  77.119188  379.977407
#
#          AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# ...

# %%
plt.hist(data['e_gap_alpha'],rwidth=0.9,bins=20)
plt.xlabel('Bandgap(eV)',fontsize=18)
plt.ylabel('Number',fontsize=18)
plt.title('The Distribution of Bangap',fontsize=20)
# Out:
# Text(0.5, 1.0, 'The Distribution of Bangap')
