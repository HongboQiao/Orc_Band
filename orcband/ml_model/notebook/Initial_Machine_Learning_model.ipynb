# %% [markdown]
# This is an example for how to using the sub module of our code.
# First, import the module.

# %%
import sys
sys.path.append("../code/")
import machine_learning_model
import pandas as pd

# %%
data = pd.read_csv('../../../documentation/data/DescriptorsDataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  e_gap_alpha    Xch-5d    AXp-0d    AXp-1d    AXp-2d    AXp-3d  \
# 0           0     1.996881  0.262189  0.655204  0.412925  0.254120  0.158333
# 1           1     2.036048  0.458607  0.653042  0.410310  0.250812  0.155235
# 2           2     1.693484  0.476265  0.651497  0.408298  0.249048  0.153825
# 3           3     1.848455  0.331927  0.653414  0.411399  0.249837  0.152563
# 4           4     2.074585  0.380040  0.655204  0.412177  0.256459  0.160971
#
#      AXp-4d    AXp-5d    AXp-6d    AXp-7d    ETA_eta  AETA_eta  ETA_eta_L  \
# 0  0.098975  0.060991  0.038411  0.024199  22.577974  0.752599   6.270874
# 1  0.096945  0.058389  0.036704  0.023043  16.897284  0.704054   5.213917
# 2  0.095116  0.056878  0.035892  0.022453  25.174481  0.899089   7.045647
# 3  0.093787  0.056820  0.034494  0.021676  25.363511  0.874604   6.773586
# 4  0.101101  0.061597  0.039310  0.024843  20.323884  0.812955   6.133003
#
#    ETA_epsilon_3
# 0       0.453846
# 1       0.454839
# ...

# %% [markdown]
# The ``machine_lerning_model.py`` contains several functions that can using the data with RDkit calculated SMILES strings to produce a figure and the score of the model. The models that listed below are:
# 1. Multipule Linear Regression
# 2. Polynomial Regression
# 3. Random Forest Regression
# 4. Neural Network Model.
#
# where the only input is data with Rdkit calculated SMILES string.

# %%
MLR_score = machine_learning_model.Multiple_Linear_Model(data)
# Out:
# The score of this regression in this case is:  0.5933711793984577

# %%
PLM_score = machine_learning_model.Polynomial_Model(data)
# Out:
# The score of this regression in this case is:  0.49999352720405454

# %%
RFR_score = machine_learning_model.Random_Forest_Model(data)
# Out:
# ../code\machine_learning_model.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train, Y_train)
# The score of this regression in this case is:  0.7024855353684127

# %%
NNM_score = machine_learning_model.Neural_Network_Model(data)
# Out:
# WARNING:tensorflow:From D:\Users\Lloyd\Miniconda3\envs\keras1.0\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Users\Lloyd\Miniconda3\envs\keras1.0\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# The score of this regression in this case is:  0.5285250551725749
