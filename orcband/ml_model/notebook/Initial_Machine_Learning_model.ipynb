# %%
import sys
sys.path.append("../code/")
import machine_learning_model
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('../../../documentation/data/DescriptorsDataset.csv')

# %%
MLR_score = machine_learning_model.Multiple_Linear_Model(data)
# Out:
# The score of this regression in this case is:  0.5933711793983547

# %%
PLM_score = machine_learning_model.Polynomial_Model(data)
# Out:
# The score of this regression in this case is:  0.49273401970122155

# %%
RFR_score = machine_learning_model.Random_Forest_Model(data)
# Out:
# ../code\Machine_Learning_Model.py:101: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train,Y_train)
# The score of this regression in this case is:  0.7024855353684127

# %%
NNM_score = machine_learning_model.Neural_Network_Model(data)
# Out:
# WARNING:tensorflow:From C:\Users\meng1\Miniconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\meng1\Miniconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# The score of this regression in this case is:  0.5221333421637118
